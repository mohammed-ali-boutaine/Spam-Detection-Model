# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import os

# %%
df = pd.read_csv("data/emails.csv",index_col=False)
df = df.drop(columns=["Unnamed: 0"])

df.columns
# Out:
# Index(['message_id', 'text', 'label', 'label_text', 'subject', 'message',
#        'date'],
#       dtype='object')

# %%
df.shape
# Out:
# (31716, 7)

# %%
df[:5]
# Out:
#    message_id                                               text  label  \
# 0       33214  any software just for 15 $ - 99 $ understandin...      1
# 1       11929  perspective on ferc regulatory action client c...      0
# 2       19784  wanted to try ci 4 lis but thought it was way ...      1
# 3        2209  enron / hpl actuals for december 11 , 2000 tec...      0
# 4       15880  looking for cheap high - quality software ? ro...      1
#
#   label_text                                            subject  \
# 0       spam                  any software just for 15 $ - 99 $
# 1        ham  perspective on ferc regulatory action client c...
# 2       spam  wanted to try ci 4 lis but thought it was way ...
# 3        ham         enron / hpl actuals for december 11 , 2000
# 4       spam  looking for cheap high - quality software ? ro...
#
#                                              message        date
# 0  understanding oem software\nlead me not into t...  2005-06-18
# ...

# %%
df.dtypes
# Out:
# message_id     int64
# text          object
# label          int64
# label_text    object
# subject       object
# message       object
# date          object
# dtype: object

# %%
df.groupby("label_text")["label_text"].count()
# Out:
# label_text
# ham     15553
# spam    16163
# Name: label_text, dtype: int64

# %% [markdown]
# ---
# Detect Duplicate Values

# %%
# df.duplicated()
# no duplicate values
df = df.drop_duplicates()

# %% [markdown]
# ---
# null values

# %%
df.isnull().sum()
# Out:
# message_id      0
# text           51
# label           0
# label_text      0
# subject       274
# message       345
# date            0
# dtype: int64

# %%
# null values percentage
total = df.size
null_vaues = df.isnull().sum().sum()
per = ((null_vaues ) / total) * 100

print("total dataset : ",total)
print("total null value : ",null_vaues)
print("null values percentage : ",per)
# Out:
# total dataset :  222012
# total null value :  670
# null values percentage :  0.3017854890726627

# %%
# null rows
df[df.isnull().any(axis=1)]
# Out:
#        message_id                                               text  label  \
# 173         20992  participate now & receive a las vegas vacation...      1
# 207         21255                                        re [ 11 ] :      1
# 218         20541                                                NaN      1
# 536         14604  http : / / albertapower . enron . com / xnav /...      0
# 554         30279  your mortgage process is pre - approved , for ...      1
# ...           ...                                                ...    ...
# 31504       31826  ninety ,\nxanaax , \ / alium , cialiis , \ / i...      1
# 31541       30976  super cheaap softwares & shiiip to all countri...      1
# 31569       13880  louise - you approved redmond hiring his curre...      0
# 31577       31849  whqfy pay f , ojr po ] rn ? ?\nas a limited ti...      1
# 31638       20622  h e l l od e a rh o m eo w n e r ,\nw eh a v e...      1
#
# ...

# %%
# drop message id and date they not important
col_to_drop = ["message_id","date"]

col_to_drop = [col for col in col_to_drop if col in df.columns]

df = df.drop(columns=col_to_drop)

# %%
text_features = ["text","subject","message"]

for col in text_features:
    df[col] = df[col].fillna("MISSING")


df.isnull().sum()
# Out:
# text          0
# label         0
# label_text    0
# subject       0
# message       0
# dtype: int64

# %% [markdown]
# ---
# ### Check if class are balanced
#
# Class A: 15,553
#
# Class B: 16,163
#
# Difference = 16,163 − 15,553 = 610
#
# Percentage difference: 610 / 16000 = 3.8%
#
# A dataset is considered balanced if the class ratio is within 10–20% difference.
#
# so the dataset is balened

# %%
df.groupby("label_text")["label_text"].count()
# Out:
# label_text
# ham     15553
# spam    16163
# Name: label_text, dtype: int64

# %% [markdown]
# ---
# ### WordClouds

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt 

df["all_text"] = df["subject"].astype(str) + " " + df["message"].astype(str) + " " + df["text"].astype(str)


spam_mask = df["label_text"] == "spam"
spam_text = " ".join((df[spam_mask]["subject"].astype(str) + " " + 
                      df[spam_mask]["message"].astype(str) + " " + 
                      df[spam_mask]["text"].astype(str)).tolist())

spam_text = " ".join(df[df["label_text"] == "spam" ]["all_text"].tolist()) 
ham_text = " ".join(df[df["label_text"] == "ham" ]["all_text"].tolist()) 


# Spam WordCloud
wc_spam = WordCloud(width=800, height=400, background_color="white").generate(spam_text)
plt.imshow(wc_spam)
plt.axis("off")
plt.title("Spam Emails WordCloud")
plt.show()

# Ham WordCloud
wc_ham = WordCloud(width=800, height=400, background_color="white").generate(ham_text)
plt.imshow(wc_ham)
plt.axis("off")
plt.title("Ham Emails WordCloud")
plt.show()

# %%
import os 

# drop all_text

df = df.drop(columns="all_text")

os.makedirs("./data/processed", exist_ok=True)

df.to_csv("./data/processed/data.csv", index=False)
